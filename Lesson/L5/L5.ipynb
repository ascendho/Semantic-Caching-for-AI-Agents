# %% [markdown]
# # L5: Fast AI Agents with a Semantic Cache

# %% [markdown]
# In this final lab, you’ll integrate your semantic cache into an AI agent so it can reuse past results, skip redundant work, and get faster over time.

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Setup Environment

# %%
from cache.llm_evaluator import set_openai_key

set_openai_key()

# %%
import logging
import time
import json
import numpy as np
import pandas as pd
from datetime import datetime
from typing import List, Dict, Any, Optional

from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langgraph.graph import StateGraph, END, START

import redis
from redisvl.utils.vectorize import HFTextVectorizer, OpenAITextVectorizer
from redisvl.extensions.cache.llm import SemanticCache
from redisvl.index import SearchIndex
from redisvl.query import VectorQuery

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s | %(levelname)s | %(message)s"
)
logger = logging.getLogger("agentic-workflow")

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
# </div>

# %% [markdown]
# ## Setup Redis Infra

# %%
redis_client = redis.Redis.from_url(
    "redis://localhost:6379", decode_responses=False
)
redis_client.ping()
# Out:
# True

# %% [markdown]
# ### Build the Agent Knowledge Base (for RAG)

# %%
from agent import create_knowledge_base_from_texts


embeddings = OpenAITextVectorizer()

raw_docs = [
    "Our premium support plan includes 24/7 phone support, priority email response within 2 hours, and dedicated account management. Premium support costs $49/month.",
    "Account upgrade process: Go to Account Settings → Plan & Billing → Select Upgrade. Available plans: Basic $9/month, Pro $29/month, Enterprise $99/month.",
    "API rate limits by plan: Free tier 100 requests/hour, Basic 1,000 requests/hour, Pro 10,000 requests/hour, Enterprise unlimited with fair-use policy.",
    "Data export options: CSV, JSON, XML formats supported. Large exports (>1GB) may take up to 24 hours to process.",
    "Third-party integrations: Native support for Slack, Microsoft Teams, Zoom, Salesforce, HubSpot. 200+ additional integrations available via Zapier.",
    "Security features: SOC2 compliance, end-to-end encryption, GDPR compliance, SSO integration, audit logs, IP whitelisting.",
    "Billing and payments: We accept all major credit cards, PayPal, and ACH transfers. Enterprise customers can pay by invoice with NET30 terms.",
    "Account recovery: Use forgot password link, verify email, or contact support with account verification details. Response within 4 hours.",
]

success, message, kb_index = create_knowledge_base_from_texts(
    texts=raw_docs,
    source_id="customer_support_docs",
    redis_url="redis://localhost:6379",
    skip_chunking=True
)
# Out:
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:kb-utils:Using provided list of 8 text chunks
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:kb-utils:✅ Created knowledge base with 8 chunks (text_list)

# %% [markdown]
# ### Build the Semantic Cache

# %%
from cache.wrapper import SemanticCacheWrapper
from cache.config import config
from cache.cross_encoder import CrossEncoder
from cache.faq_data_container import FAQDataContainer

cache = SemanticCacheWrapper.from_config(config)

data = FAQDataContainer()
cache.hydrate_from_df(data.faq_df, clear=True)
# Out:
# ✅ Redis is running and accessible!
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: redis/langcache-embed-v1
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/596M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# Loaded 8 FAQ entries
# Loaded 80 test queries

# %% [markdown]
# ## Build the LangGraph Agent

# %%
from agent import (
    WorkflowState,
    initialize_agent,
    decompose_query_node,
    check_cache_node,
    research_node,
    evaluate_quality_node,
    synthesize_response_node,
    route_after_cache_check,
    route_after_quality_evaluation,
)

initialize_agent(cache, kb_index, embeddings)

# %%
workflow = StateGraph(WorkflowState)

# Add nodes 
workflow.add_node("decompose_query", decompose_query_node)
workflow.add_node("check_cache", check_cache_node)
workflow.add_node("research", research_node)
workflow.add_node("evaluate_quality", evaluate_quality_node)
workflow.add_node("synthesize", synthesize_response_node)

# Set entry point to decomposition node
workflow.set_entry_point("decompose_query")

# Add edges
workflow.add_edge("decompose_query", "check_cache")
workflow.add_conditional_edges(
    "check_cache",
    route_after_cache_check,
    {
        "research": "research",  # Go to research if cache misses
        "synthesize": "synthesize",  # Skip to synthesis if all cached
    },
)
workflow.add_edge("research", "evaluate_quality")
workflow.add_conditional_edges(
    "evaluate_quality",
    route_after_quality_evaluation,
    {
        "research": "research",
        "synthesize": "synthesize",
    },
)
workflow.add_edge("synthesize", END)

workflow_app = workflow.compile()

# %%
from IPython.display import Image, display

display(Image(workflow_app.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Demo the Agent

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output visualizations generated may differ from those shown in the video.</p>

# %%
from agent import display_results
from agent import run_agent

# %% [markdown]
# ### Scenario 1: Enterprise Platform Evaluation (cache building phase)

# %%
scenario1_query = """
I'm evaluating your platform for our enterprise needs. We need to understand your 
security and compliance standards including SOC2 status, want to know the API rate 
limits for the Pro plan since we're considering that tier, need details about 
Salesforce integration capabilities, and want to understand your payment options 
including whether you support ACH transfers.
"""

result1 = run_agent(workflow_app, scenario1_query)
display_results(result1)
# Out:
# INFO:agentic-workflow:================================================================================
# INFO:agentic-workflow:🧠 Decomposing query...
# INFO:agentic-workflow:🧠 Supervisor: Decomposing query: '
# I'm evaluating your platform for our enterprise n...'
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🧠 Decomposed into 4 sub-questions in 80.20ms
# INFO:agentic-workflow:   1. What are your security and compliance standards, including your current SOC2 status?
# INFO:agentic-workflow:   2. What are the API rate limits for the Pro plan?
# INFO:agentic-workflow:   3. What are your Salesforce integration capabilities?
# INFO:agentic-workflow:   4. What payment options do you offer, and do you support ACH transfers?
# INFO:agentic-workflow:🧠 Query decomposition complete
# INFO:agentic-workflow:🔍 Supervisor: Checking cache for 4 sub-questions
# INFO:agentic-workflow:   ❌ Cache MISS: 'What are your security and compliance st...'
# INFO:agentic-workflow:   ❌ Cache MISS: 'What are the API rate limits for the Pro...'
# INFO:agentic-workflow:   ❌ Cache MISS: 'What are your Salesforce integration cap...'
# INFO:agentic-workflow:   ✅ Cache HIT: 'What payment options do you offer, and d...' (confidence: 0.888)
# INFO:agentic-workflow:🔍 Cache check complete: 1/4 hits (25.0%) in 135.97ms
# INFO:agentic-workflow:🔀 Routing to researcher: 3 cache misses detected
# INFO:agentic-workflow:   🔍 Will research: 'What are your security and compliance standards, i...'
# INFO:agentic-workflow:   🔍 Will research: 'What are the API rate limits for the Pro plan?...'
# INFO:agentic-workflow:   🔍 Will research: 'What are your Salesforce integration capabilities?...'
# INFO:agentic-workflow:🔬 Research: Starting investigation with strategy adaptation
# INFO:agentic-workflow:🔍 Researching: 'What are your security and compliance standards, i...' (iteration 1, strategy: initial)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🔍 Using search_knowledge_base tool for query: 'security and compliance standards SOC2 status' (top_k=3)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ Research complete (iteration 1): 'Our security and compliance standards include SOC2 complianc...'
# INFO:agentic-workflow:🔍 Researching: 'What are the API rate limits for the Pro plan?...' (iteration 1, strategy: initial)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🔍 Using search_knowledge_base tool for query: 'API rate limits for the Pro plan' (top_k=3)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ Research complete (iteration 1): 'The API rate limits for the Pro plan are 10,000 requests per...'
# INFO:agentic-workflow:🔍 Researching: 'What are your Salesforce integration capabilities?...' (iteration 1, strategy: initial)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ Research complete (iteration 1): 'I can help with Salesforce integration in several ways, incl...'
# INFO:agentic-workflow:🔬 Research complete: 3 questions researched in 502.78ms
# INFO:agentic-workflow:🎯 Quality Evaluation: Evaluating research quality for 4 answers
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ What are your security and compliance st... - Score: 0.80 - Adequate
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ What are the API rate limits for the Pro... - Score: 0.80 - Adequate
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ What are your Salesforce integration cap... - Score: 0.90 - Adequate
# INFO:agentic-workflow:🎯 Quality evaluation complete in 162.78ms
# INFO:agentic-workflow:📊 0 sub-questions need additional research
# INFO:agentic-workflow:🔀 Routing to synthesis: all research quality is adequate!
# INFO:agentic-workflow:   💾 Cached validated research: 'What are your security and compliance st...'
# INFO:agentic-workflow:   💾 Cached validated research: 'What are the API rate limits for the Pro...'
# INFO:agentic-workflow:   💾 Cached validated research: 'What are your Salesforce integration cap...'
# INFO:agentic-workflow:✅ Cached 3 validated research results
# INFO:agentic-workflow:🔗 Supervisor: Synthesizing 4 answers into final response
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🔗 Response synthesized in 72.80ms
# INFO:agentic-workflow:📝 Final response: Thank you for considering our platform for your enterprise needs! I’m happy to provide a comprehensi...
# INFO:agentic-workflow:================================================================================
# INFO:agentic-workflow:✅ Workflow query completed in 975.74ms
# \n🎯 SEMANTIC CACHING WORKFLOW ANALYSIS
# ================================================================================
# 📝 **Original Query:**
# I'm evaluating your platform for our enterprise needs. We need to understand your
# security and com...
# 🔄 **Execution Path:** decomposed → cache_checked → researched → quality_evaluated → synthesized
# \n🧠 **Query Decomposition:** 4 sub-questions
#    1. 🔍 **RESEARCH**: What are your security and compliance standards, including your current SOC2 status?
#    2. 🔍 **RESEARCH**: What are the API rate limits for the Pro plan?
#    3. 🔍 **RESEARCH**: What are your Salesforce integration capabilities?
#    4. ✅ **CACHE HIT** (0.888): What payment options do you offer, and do you support ACH transfers?
# \n📊 **Performance Metrics:**
#    💾 Cache Hit Rate: **25.0%** (1/4 questions)
#    🤖 LLM Calls: **8** (GPT-4: 2, GPT-4-Mini: 6)
#    ⚡ Total Latency: **975.74ms**
#    ⏱️  Cache: 136ms, Research: 503ms
# \n📋 **AI Response:**
# --------------------------------------------------------------------------------
# Thank you for considering our platform for your enterprise needs! I’m happy to provide a comprehensive overview addressing your questions about security, API limits, Salesforce integration, and payment options.
#
# **Security & Compliance:**
# We take security and compliance very seriously. Our platform is SOC2 compliant and features end-to-end encryption, GDPR compliance, SSO integration, audit logs, and IP whitelisting. If you need more detailed documentation or have specific compliance requirements, please let me know—I’d be glad to provide additional information.
#
# **API Rate Limits (Pro Plan):**
# For the Pro plan, the API rate limit is 10,000 requests per hour. This should provide ample capacity for most enterprise use cases, but if you anticipate higher volumes or have unique integration needs, we can discuss potential solutions.
#
# **Salesforce Integration Capabilities:**
# We offer robust Salesforce integration options, including:
#
# - Data synchronization between Salesforce and other systems or databases
# - Guidance on using Salesforce APIs (REST, SOAP, Bulk API) for data access and manipulation
# - Assistance with setting up workflows, triggers, and process automation within Salesforce
# - Support for custom development (Apex code, Lightning components, Visualforce pages)
# - Help with creating reports, dashboards, and integrating Salesforce data with BI tools
# - Integration with third-party platforms such as marketing automation, ERP, and customer support tools
#
# If you have a specific integration scenario in mind, please share more details so I can provide tailored guidance or technical assistance.
#
# **Payment Options:**
# We offer flexible payment options, including all major credit cards, PayPal, Apple Pay, Google Pay, and bank transfers for orders over $100. ACH transfers are supported through our bank transfer option.
#
# If you have any further questions or would like to discuss your requirements in more detail, please let me know—I’m here to help!
# --------------------------------------------------------------------------------
# ================================================================================

# %% [markdown]
# ### Scenario 2: Implementation Planning (partial cache hits likely)

# %%
scenario2_query = """
We're moving forward with implementation planning. I need to compare API rate limits 
between Pro and Enterprise plans to decide on our tier, confirm the Salesforce 
integration capabilities we discussed, understand what data export options you provide 
for our migration needs, and verify the payment methods including ACH since our 
accounting team prefers that for monthly billing.
"""

result2 = run_agent(workflow_app, scenario2_query)
display_results(result2)
# Out:
# INFO:agentic-workflow:================================================================================
# INFO:agentic-workflow:🧠 Decomposing query...
# INFO:agentic-workflow:🧠 Supervisor: Decomposing query: '
# We're moving forward with implementation planning...'
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🧠 Decomposed into 4 sub-questions in 73.99ms
# INFO:agentic-workflow:   1. What are the API rate limits for the Pro and Enterprise plans?
# INFO:agentic-workflow:   2. What Salesforce integration capabilities are available?
# INFO:agentic-workflow:   3. What data export options are provided for migration purposes?
# INFO:agentic-workflow:   4. What payment methods are supported, specifically is ACH available for monthly billing?
# INFO:agentic-workflow:🧠 Query decomposition complete
# INFO:agentic-workflow:🔍 Supervisor: Checking cache for 4 sub-questions
# INFO:agentic-workflow:   ✅ Cache HIT: 'What are the API rate limits for the Pro...' (confidence: 0.947)
# INFO:agentic-workflow:   ✅ Cache HIT: 'What Salesforce integration capabilities...' (confidence: 0.924)
# INFO:agentic-workflow:   ❌ Cache MISS: 'What data export options are provided fo...'
# INFO:agentic-workflow:   ✅ Cache HIT: 'What payment methods are supported, spec...' (confidence: 0.857)
# INFO:agentic-workflow:🔍 Cache check complete: 3/4 hits (75.0%) in 172.01ms
# INFO:agentic-workflow:🔀 Routing to researcher: 1 cache misses detected
# INFO:agentic-workflow:   🔍 Will research: 'What data export options are provided for migratio...'
# INFO:agentic-workflow:🔬 Research: Starting investigation with strategy adaptation
# INFO:agentic-workflow:🔍 Researching: 'What data export options are provided for migratio...' (iteration 1, strategy: initial)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🔍 Using search_knowledge_base tool for query: 'data export options for migration' (top_k=3)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ Research complete (iteration 1): 'For migration purposes, the data export options provided inc...'
# INFO:agentic-workflow:🔬 Research complete: 1 questions researched in 204.77ms
# INFO:agentic-workflow:🎯 Quality Evaluation: Evaluating research quality for 4 answers
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ What data export options are provided fo... - Score: 0.80 - Adequate
# INFO:agentic-workflow:🎯 Quality evaluation complete in 78.84ms
# INFO:agentic-workflow:📊 0 sub-questions need additional research
# INFO:agentic-workflow:🔀 Routing to synthesis: all research quality is adequate!
# INFO:agentic-workflow:   💾 Cached validated research: 'What data export options are provided fo...'
# INFO:agentic-workflow:✅ Cached 1 validated research results
# INFO:agentic-workflow:🔗 Supervisor: Synthesizing 4 answers into final response
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🔗 Response synthesized in 81.03ms
# INFO:agentic-workflow:📝 Final response: Thank you for reaching out with your questions as you move forward with implementation planning. I’m...
# INFO:agentic-workflow:================================================================================
# INFO:agentic-workflow:✅ Workflow query completed in 620.68ms
# \n🎯 SEMANTIC CACHING WORKFLOW ANALYSIS
# ================================================================================
# 📝 **Original Query:**
# We're moving forward with implementation planning. I need to compare API rate limits
# between Pro a...
# 🔄 **Execution Path:** decomposed → cache_checked → researched → quality_evaluated → synthesized
# \n🧠 **Query Decomposition:** 4 sub-questions
#    1. ✅ **CACHE HIT** (0.947): What are the API rate limits for the Pro and Enterprise plans?
#    2. ✅ **CACHE HIT** (0.924): What Salesforce integration capabilities are available?
#    3. 🔍 **RESEARCH**: What data export options are provided for migration purposes?
#    4. ✅ **CACHE HIT** (0.857): What payment methods are supported, specifically is ACH available for monthly billing?
# \n📊 **Performance Metrics:**
#    💾 Cache Hit Rate: **75.0%** (3/4 questions)
#    🤖 LLM Calls: **4** (GPT-4: 2, GPT-4-Mini: 2)
#    ⚡ Total Latency: **620.68ms**
#    ⏱️  Cache: 172ms, Research: 205ms
# \n📋 **AI Response:**
# --------------------------------------------------------------------------------
# Thank you for reaching out with your questions as you move forward with implementation planning. I’m happy to provide a comprehensive overview to help you make the best decision for your team.
#
# For API rate limits, the Pro plan allows for 10,000 requests per hour. If you anticipate higher usage or have specific needs around API throughput, please let me know, and I can provide details on the Enterprise plan’s limits or help you assess which tier would be the best fit.
#
# Regarding Salesforce integration, we offer robust capabilities, including data synchronization between Salesforce and other systems, guidance on using Salesforce APIs (REST, SOAP, Bulk API), setting up automation (workflows, triggers, process automation), and support for custom development (Apex code, Lightning components, Visualforce pages). We can also assist with reporting, analytics, and integrating Salesforce with third-party platforms such as marketing automation, ERP, and customer support tools. If you have a particular integration scenario in mind, please share more details so I can provide tailored guidance.
#
# For your migration needs, we support data exports in CSV, JSON, and XML formats. Please note that exports over 1GB may take up to 24 hours to process. If you need assistance with the export process or have specific requirements, I’m here to help.
#
# In terms of payment methods, we accept all major credit cards, PayPal, Apple Pay, Google Pay, and bank transfers (ACH) for orders over $100. This should align well with your accounting team’s preference for ACH for monthly billing.
#
# If you need more detailed information on any of these points or have additional questions, please let me know—I’m here to support you every step of the way!
# --------------------------------------------------------------------------------
# ================================================================================

# %% [markdown]
# ### Scenario 3: Pre-Purchase Comprehensive Review (many cache hits expected)

# %%
scenario3_query = """
Before finalizing our Pro plan purchase, I need complete validation on: your security 
compliance framework including SOC2 requirements, the exact API rate limits for the 
Pro plan we're purchasing, confirmation of the Salesforce integration features, all 
supported payment methods since we want to use ACH transfers, and your data export 
capabilities for our future migration planning.
"""

result3 = run_agent(workflow_app, scenario3_query)
display_results(result3)
# Out:
# INFO:agentic-workflow:================================================================================
# INFO:agentic-workflow:🧠 Decomposing query...
# INFO:agentic-workflow:🧠 Supervisor: Decomposing query: '
# Before finalizing our Pro plan purchase, I need c...'
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🧠 Decomposed into 4 sub-questions in 56.30ms
# INFO:agentic-workflow:   1. What is your security compliance framework, specifically regarding SOC2 requirements, for the Pro plan?
# INFO:agentic-workflow:   2. What are the exact API rate limits for the Pro plan we are considering?
# INFO:agentic-workflow:   3. What Salesforce integration features are included with the Pro plan?
# INFO:agentic-workflow:   4. What payment methods are supported, and do you support ACH transfers?
# INFO:agentic-workflow:🧠 Query decomposition complete
# INFO:agentic-workflow:🔍 Supervisor: Checking cache for 4 sub-questions
# INFO:agentic-workflow:   ✅ Cache HIT: 'What is your security compliance framewo...' (confidence: 0.906)
# INFO:agentic-workflow:   ✅ Cache HIT: 'What are the exact API rate limits for t...' (confidence: 0.971)
# INFO:agentic-workflow:   ❌ Cache MISS: 'What Salesforce integration features are...'
# INFO:agentic-workflow:   ✅ Cache HIT: 'What payment methods are supported, and ...' (confidence: 0.893)
# INFO:agentic-workflow:🔍 Cache check complete: 3/4 hits (75.0%) in 130.39ms
# INFO:agentic-workflow:🔀 Routing to researcher: 1 cache misses detected
# INFO:agentic-workflow:   🔍 Will research: 'What Salesforce integration features are included ...'
# INFO:agentic-workflow:🔬 Research: Starting investigation with strategy adaptation
# INFO:agentic-workflow:🔍 Researching: 'What Salesforce integration features are included ...' (iteration 1, strategy: initial)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🔍 Using search_knowledge_base tool for query: 'Salesforce integration features Pro plan' (top_k=3)
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ Research complete (iteration 1): 'The Pro plan includes native support for Salesforce integrat...'
# INFO:agentic-workflow:🔬 Research complete: 1 questions researched in 178.61ms
# INFO:agentic-workflow:🎯 Quality Evaluation: Evaluating research quality for 4 answers
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:   ✅ What Salesforce integration features are... - Score: 0.80 - Adequate
# INFO:agentic-workflow:🎯 Quality evaluation complete in 52.00ms
# INFO:agentic-workflow:📊 0 sub-questions need additional research
# INFO:agentic-workflow:🔀 Routing to synthesis: all research quality is adequate!
# INFO:agentic-workflow:   💾 Cached validated research: 'What Salesforce integration features are...'
# INFO:agentic-workflow:✅ Cached 1 validated research results
# INFO:agentic-workflow:🔗 Supervisor: Synthesizing 4 answers into final response
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/chat/completions "HTTP/1.1 200 OK"
# INFO:agentic-workflow:🔗 Response synthesized in 72.11ms
# INFO:agentic-workflow:📝 Final response: Thank you for reaching out with your detailed questions before finalizing your Pro plan purchase—I'm...
# INFO:agentic-workflow:================================================================================
# INFO:agentic-workflow:✅ Workflow query completed in 497.96ms
# \n🎯 SEMANTIC CACHING WORKFLOW ANALYSIS
# ================================================================================
# 📝 **Original Query:**
# Before finalizing our Pro plan purchase, I need complete validation on: your security
# compliance f...
# 🔄 **Execution Path:** decomposed → cache_checked → researched → quality_evaluated → synthesized
# \n🧠 **Query Decomposition:** 4 sub-questions
#    1. ✅ **CACHE HIT** (0.906): What is your security compliance framework, specifically regarding SOC2 requirements, for the Pro plan?
#    2. ✅ **CACHE HIT** (0.971): What are the exact API rate limits for the Pro plan we are considering?
#    3. 🔍 **RESEARCH**: What Salesforce integration features are included with the Pro plan?
#    4. ✅ **CACHE HIT** (0.893): What payment methods are supported, and do you support ACH transfers?
# \n📊 **Performance Metrics:**
#    💾 Cache Hit Rate: **75.0%** (3/4 questions)
#    🤖 LLM Calls: **4** (GPT-4: 2, GPT-4-Mini: 2)
#    ⚡ Total Latency: **497.96ms**
#    ⏱️  Cache: 130ms, Research: 179ms
# \n📋 **AI Response:**
# --------------------------------------------------------------------------------
# Thank you for reaching out with your detailed questions before finalizing your Pro plan purchase—I'm happy to provide all the information you need.
#
# Regarding security and compliance, our platform adheres to robust standards, including SOC2 compliance, end-to-end encryption, GDPR compliance, SSO integration, audit logs, and IP whitelisting. If you require more in-depth documentation or have specific compliance questions, please let me know and I can provide further details.
#
# For API usage, the Pro plan offers a rate limit of 10,000 requests per hour. This should provide ample capacity for most integration and automation needs.
#
# In terms of Salesforce integration, the Pro plan includes native support for Salesforce as part of its third-party integrations. You can connect Salesforce directly without the need for additional middleware, and the 10,000 API requests per hour limit applies to these integrations as well.
#
# When it comes to payment methods, we accept all major credit cards, PayPal, Apple Pay, Google Pay, and bank transfers (ACH transfers) for orders over $100. This should give you the flexibility to use ACH for your purchase.
#
# Lastly, regarding data export capabilities for future migration planning, our platform allows you to export your data at any time. We support standard export formats to ensure your data is portable and can be migrated as needed.
#
# If you need more specific documentation or have any other questions, please let me know—I'm here to help ensure you have everything you need to make an informed decision!
# --------------------------------------------------------------------------------
# ================================================================================

# %% [markdown]
# ## Agent Performance Analysis

# %%
import warnings
warnings.simplefilter("ignore")

from agent import analyze_agent_results

total_questions, total_cache_hits = analyze_agent_results(
    [result1, result2, result3]
)
# Out:
# INFO:matplotlib.font_manager:generated new fontManager

# %% [markdown]
# ## Interactive Demo

# %% [markdown]
# Here is the link we used in the video for this section:
# * https://att.com/international

# %%
from agent import launch_demo

launch_demo(
    workflow_app,
    cache,
    share=True,
    height=1500,
    inline=True
)
# Out:
# INFO:demo:Using Tavily API key from environment
# INFO:httpx:HTTP Request: POST http://jupyter-api-proxy.internal.dlai/rev-proxy/openai/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://s172-29-25-171p7860.lab-aws-production.deeplearning.ai/gradio_api/startup-events "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://s172-29-25-171p7860.lab-aws-production.deeplearning.ai/ "HTTP/1.1 200 OK"
# * Running on local URL:  https://0.0.0.0:7860
# INFO:httpx:HTTP Request: GET https://api.gradio.app/v3/tunnel-request "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://cdn-media.huggingface.co/frpc-gradio-0.3/frpc_linux_amd64 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://37356cb3f9754bf1ba.gradio.live "HTTP/1.1 200 OK"
# * Running on public URL: https://37356cb3f9754bf1ba.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://37356cb3f9754bf1ba.gradio.live" width="100%" height="1500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
cache.cache.check(
    "checking cache", distance_threshold=1.0, num_results=100
)
# Out:
# [{'entry_id': '6951ac186c3c6207f25a11ebc9bd96c888b38fa33838cd138e1366e836a36ed7',
#   'prompt': 'Where is my order?',
#   'response': 'Use the tracking link sent to your email after shipping. Orders typically arrive within 2-7 business days depending on your location.',
#   'vector_distance': 0.477180957794,
#   'inserted_at': 1775735588.56,
#   'updated_at': 1775735588.56,
#   'key': 'semantic-cache:6951ac186c3c6207f25a11ebc9bd96c888b38fa33838cd138e1366e836a36ed7'},
#  {'entry_id': '60fd55b8527fcd2bf427d81dc3f4c47c4bf8904c9802ffecbcf2c02b38f537ac',
#   'prompt': 'How do I get a refund?',
#   'response': 'To request a refund, visit your orders page and select **Request Refund**. Refunds are processed within 3-5 business days.',
#   'vector_distance': 0.481174767017,
#   'inserted_at': 1775735588.47,
#   'updated_at': 1775735588.47,
#   'key': 'semantic-cache:60fd55b8527fcd2bf427d81dc3f4c47c4bf8904c9802ffecbcf2c02b38f537ac'},
#  {'entry_id': '7874cebc1fee0857ed3fc223829e2ff2e520bc96bb69a06d08a41b77e373eba3',
#   'prompt': 'What are your security and compliance standards, including your current SOC2 status?',
#   'response': 'Our security and compliance standards include SOC2 compliance, end-to-end encryption, GDPR compliance, SSO integration, audit logs, and IP whitelisting. If you need more detailed information about any specific aspect, please let me know!',
#   'vector_distance': 0.519352972507,
#   'inserted_at': 1775735590.94,
#   'updated_at': 1775735590.94,
#   'key': 'semantic-cache:7874cebc1fee0857ed3fc223829e2ff2e520bc96bb69a06d08a41b77e373eba3'},
#  {'entry_id': '6e256e6e56a2afb5d089be3cb4cc51ada871f547f333616d9dd261e1fcca5e20',
#   'prompt': 'How long is the warranty?',
#   'response': 'All electronic products include a 12-month warranty from the purchase date. Extended warranties are available for purchase.',
#   'vector_distance': 0.523474633694,
#   'inserted_at': 1775735588.6,
#   'updated_at': 1775735588.6,
#   'key': 'semantic-cache:6e256e6e56a2afb5d089be3cb4cc51ada871f547f333616d9dd261e1fcca5e20'},
#  {'entry_id': '3033519f424c6c9191aaa30479010830294d8d9e35a4208bef0abe0bc4e28f25',
#   'prompt': 'What payment methods do you accept?',
#   'response': 'We accept all major credit cards, PayPal, Apple Pay, Google Pay, and bank transfers for orders over $100.',
#   'vector_distance': 0.539579510689,
#   'inserted_at': 1775735588.73,
#   'updated_at': 1775735588.73,
#   'key': 'semantic-cache:3033519f424c6c9191aaa30479010830294d8d9e35a4208bef0abe0bc4e28f25'},
#  {'entry_id': '37c89923439de45c2b754bf77bed2fe5f887d8e2bb076a9be1f496ef9ee4e559',
#   'prompt': 'Do you ship internationally?',
#   'response': 'Yes, we ship to over 50 countries worldwide. International shipping fees and delivery times vary by destination.',
#   'vector_distance': 0.584227323532,
#   'inserted_at': 1775735588.64,
#   'updated_at': 1775735588.64,
#   'key': 'semantic-cache:37c89923439de45c2b754bf77bed2fe5f887d8e2bb076a9be1f496ef9ee4e559'},
#  {'entry_id': '2acad2bd00173c0d98e293c61ee6c882355ce366b614cb9f7045701f5de7f357',
#   'prompt': 'How do I cancel my subscription?',
#   'response': "Go to Account Settings > Subscriptions and click **Cancel Subscription**. You'll retain access until your current billing period ends.",
#   'vector_distance': 0.588650047779,
#   'inserted_at': 1775735588.69,
#   'updated_at': 1775735588.69,
#   'key': 'semantic-cache:2acad2bd00173c0d98e293c61ee6c882355ce366b614cb9f7045701f5de7f357'},
#  {'entry_id': 'c00687a2004750d3e4f0cbdae84c69abc6d7f1c3f37a23f22d4ee6dc336afa66',
#   'prompt': 'Can I reset my password?',
#   'response': "Click **Forgot Password** on the login page and follow the email instructions. Check your spam folder if you don't see the email.",
#   'vector_distance': 0.58925485611,
#   'inserted_at': 1775735588.51,
#   'updated_at': 1775735588.51,
#   'key': 'semantic-cache:c00687a2004750d3e4f0cbdae84c69abc6d7f1c3f37a23f22d4ee6dc336afa66'},
#  {'entry_id': '16b83e927252aacb1c9d8dcc409133c12e0abff55ef2bbdcf90ab7331d2e2304',
#   'prompt': 'What data export options are provided for migration purposes?',
#   'response': 'For migration purposes, the data export options provided include CSV, JSON, and XML formats. Note that large exports over 1GB may take up to 24 hours to process. If you need more detailed information or assistance with the export process, feel free to ask!',
#   'vector_distance': 0.610069394112,
#   'inserted_at': 1775735591.56,
#   'updated_at': 1775735591.56,
#   'key': 'semantic-cache:16b83e927252aacb1c9d8dcc409133c12e0abff55ef2bbdcf90ab7331d2e2304'},
#  {'entry_id': '16c2e738808a3b74ff1ca61730afd3882f28c72e2d49227e04d2ba61452cf3e0',
#   'prompt': 'What are the API rate limits for the Pro plan?',
#   'response': 'The API rate limits for the Pro plan are 10,000 requests per hour.',
#   'vector_distance': 0.611371040344,
#   'inserted_at': 1775735590.94,
#   'updated_at': 1775735590.94,
#   'key': 'semantic-cache:16c2e738808a3b74ff1ca61730afd3882f28c72e2d49227e04d2ba61452cf3e0'},
#  {'entry_id': 'a91b448fc4cb0da823ba2f8f461467727168f11a2ffc43fb6a2b201524c8fa9d',
#   'prompt': 'Can I change my delivery address?',
#   'response': 'You can update your delivery address before your order ships. Go to Orders > Modify Delivery Address.',
#   'vector_distance': 0.620533227921,
#   'inserted_at': 1775735588.78,
#   'updated_at': 1775735588.78,
#   'key': 'semantic-cache:a91b448fc4cb0da823ba2f8f461467727168f11a2ffc43fb6a2b201524c8fa9d'},
#  {'entry_id': '54d98ee6f44bbb4241b94943edaef91a10ae7494ab0080fbaa4d902f6c2c9d64',
#   'prompt': 'What are your Salesforce integration capabilities?',
#   'response': 'I can help with Salesforce integration in several ways, including:\n\n1. Data Synchronization: Assisting in syncing data between Salesforce and other systems or databases.\n2. API Usage: Guiding on how to use Salesforce APIs (REST, SOAP, Bulk API) for data access and manipulation.\n3. Automation: Helping set up workflows, triggers, and process automation within Salesforce.\n4. Custom Development: Advising on custom Apex code, Lightning components, and Visualforce pages.\n5. Reporting and Analytics: Assisting in creating reports, dashboards, and integrating Salesforce data with BI tools.\n6. Third-Party Integrations: Supporting integration with other platforms like marketing automation, ERP, and customer support tools.\n\nIf you have a specific integration scenario or requirement, please share more details, and I can provide tailored guidance or technical assistance.',
#   'vector_distance': 0.638659060001,
#   'inserted_at': 1775735590.94,
#   'updated_at': 1775735590.94,
#   'key': 'semantic-cache:54d98ee6f44bbb4241b94943edaef91a10ae7494ab0080fbaa4d902f6c2c9d64'},
#  {'entry_id': 'dfaa525137dce923c635cde705e2893900d3edd9b01e0768c4e9986c8086d2e2',
#   'prompt': 'What Salesforce integration features are included with the Pro plan?',
#   'response': 'The Pro plan includes native support for Salesforce integration as part of its third-party integrations. This means you can directly integrate Salesforce with the Pro plan without needing additional tools. Additionally, the Pro plan allows for up to 10,000 API requests per hour, which can be relevant for integration usage.',
#   'vector_distance': 0.644053995609,
#   'inserted_at': 1775735592.07,
#   'updated_at': 1775735592.07,
#   'key': 'semantic-cache:dfaa525137dce923c635cde705e2893900d3edd9b01e0768c4e9986c8086d2e2'}]
